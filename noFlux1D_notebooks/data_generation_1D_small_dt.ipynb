# %% [markdown]
# # Notebook used to generate data for $\Delta t = 0.000625$ and $0.00015625$

# %% [markdown]
# ## Setting up

# %%
import numpy as np
import matplotlib.pyplot as plt

import os

# %%
import sys
sys.path.append("..")

# %%
from sources.simulation import numerical_solution, euler_maruyama
from sources.analysis import stationary_solution
from sources.models import *
from sources.data_storage import *

# %%
#defind varaibles

#10 mil
n_parts = 10000000

T = 2

dt_list = [0.000625]#, 0.00015625]

#set the boundries
x_bounds = (0, 1)


X_0 = np.random.uniform(.45,.55, n_parts)

theta_list = [0.25, 0.5, 0.75]

boundaries = ["reflection", "rejection"]#, "theta", "half_step"]

# %% [markdown]
# ## Case $b=0$ and $\sigma = 1$

# %%
b = lambda x, t=None: constant_drift(x, value=0)
sigma = lambda x, t=None: constant_diffusion(x, value=1)

path = "./data/b-0_s-1"

for dt in dt_list:

    n_steps = int(T/dt)

    for boundary in boundaries:
        if boundary == "theta":
            for theta in theta_list:
                X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                     , b=b, sigma=sigma, boundary_type=(boundary, theta)
                                                     , boundaries=x_bounds)
                # filename = boundary + "-" + theta + "_dt-" + dt
                filename = (f"{boundary}-{theta}_dt-{dt}")
                save_solution(X, filename, path)

        else:
            X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                                 , b=b, sigma=sigma, boundary_type=boundary
                                                                 , boundaries=x_bounds)
            filename = (f"{boundary}_dt-{dt}")
            save_solution(X, filename, path)

    
    print(f"finished {dt=}")


del sigma, b
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 21
#      18         save_solution(X, filename, path)
#      20 else:
# ---> 21     X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
#      22                                                          , b=b, sigma=sigma, boundary_type=boundary
#      23                                                          , boundaries=x_bounds)
#      24     filename = (f"{boundary}_dt-{dt}")
#      25     save_solution(X, filename, path)
#
# File /workspaces/dissertation-project/noFlux1D_notebooks/../sources/simulation.py:202, in numerical_solution(method, X_0, dt, n_steps, b, sigma, boundary_type, boundaries)
#     199 X_current = X_0.copy()
#     201 for i in range(n_steps):
# --> 202     X_current = method(X_current=X_current, dt=dt, b=b, sigma=sigma
#     203                        , boundary_type=boundary_type, boundaries=boundaries)
#     205 return X_current
#
# File /workspaces/dissertation-project/noFlux1D_notebooks/../sources/simulation.py:178, in euler_maruyama(X_current, dt, b, sigma, boundary_type, boundaries, xi)
#     174 def euler_maruyama(X_current, dt, b, sigma, boundary_type, boundaries, xi=None):
#     177     if xi is None:
# --> 178         xi = np.random.normal(0, 1, size=X_current.shape)
#     180     proposal = X_current + b(X_current) * dt + sigma(X_current) * np.sqrt(dt) * xi
#     182     return apply_boundary(proposal=proposal, X_current=X_current, boundary_type=boundary_type,
#     183         boundaries=boundaries)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Case $b=1$ and $\sigma = 1$

# %%
b = lambda x, t=None: constant_drift(x, value=1)
sigma = lambda x, t=None: constant_diffusion(x, value=1)

path = "./data/b-1_s-1"

for dt in dt_list:

    n_steps = int(T/dt)

    for boundary in boundaries:
        if boundary == "theta":
            for theta in theta_list:
                X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                     , b=b, sigma=sigma, boundary_type=(boundary, theta)
                                                     , boundaries=x_bounds)
                # filename = boundary + "-" + theta + "_dt-" + dt
                filename = (f"{boundary}-{theta}_dt-{dt}")
                save_solution(X, filename, path)

        else:
            X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                                 , b=b, sigma=sigma, boundary_type=boundary
                                                                 , boundaries=x_bounds)
            filename = (f"{boundary}_dt-{dt}")
            save_solution(X, filename, path)

    
    print(f"finished {dt=}")


del sigma, b
# Out:
# finished dt=0.000625

# %% [markdown]
# ## Case $b=0$ and $\sigma(x) = x+1$

# %%
b = lambda x, t=None: constant_drift(x, value=0)
sigma = lambda x, t=None: linear_diffusion(x, slope=1, intercept=1)

path = "./data/b-0_s-xp1"

for dt in dt_list:

    n_steps = int(T/dt)

    for boundary in boundaries:
        if boundary == "theta":
            for theta in theta_list:
                X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                     , b=b, sigma=sigma, boundary_type=(boundary, theta)
                                                     , boundaries=x_bounds)
                # filename = boundary + "-" + theta + "_dt-" + dt
                filename = (f"{boundary}-{theta}_dt-{dt}")
                save_solution(X, filename, path)

        else:
            X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                                 , b=b, sigma=sigma, boundary_type=boundary
                                                                 , boundaries=x_bounds)
            filename = (f"{boundary}_dt-{dt}")
            save_solution(X, filename, path)

    
    print(f"finished {dt=}")


del sigma, b
# Out:
# finished dt=0.000625

# %% [markdown]
# ## Case $b=1$ and $\sigma(x) = x+1$

# %%
b = lambda x, t=None: constant_drift(x, value=1)
sigma = lambda x, t=None: linear_diffusion(x, slope=1, intercept=1)

path = "./data/b-1_s-xp1"

for dt in dt_list:

    n_steps = int(T/dt)

    for boundary in boundaries:
        if boundary == "theta":
            for theta in theta_list:
                X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                     , b=b, sigma=sigma, boundary_type=(boundary, theta)
                                                     , boundaries=x_bounds)
                # filename = boundary + "-" + theta + "_dt-" + dt
                filename = (f"{boundary}-{theta}_dt-{dt}")
                save_solution(X, filename, path)

        else:
            X = numerical_solution(method=euler_maruyama, X_0=X_0, dt=dt, n_steps=n_steps
                                                                 , b=b, sigma=sigma, boundary_type=boundary
                                                                 , boundaries=x_bounds)
            filename = (f"{boundary}_dt-{dt}")
            save_solution(X, filename, path)

    
    print(f"finished {dt=}")
# Out:
# finished dt=0.000625
